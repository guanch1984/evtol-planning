# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_heliport = pd.read_csv('data/us-heliports-landing-facilities.csv')  
mask = (df_heliport['SHAPE_X'] <-50) & (df_heliport['SHAPE_X'] > -140) & (df_heliport['SHAPE_Y'] <50) & (df_heliport['SHAPE_Y'] > 22)
df_heliport = df_heliport[mask]
df_heliport.head()
# Out:
#                                           WKT  Enplanements  Passengers  \
# 0  POINT (-74.8227500004275 41.1261777780373)           NaN         NaN
# 1  POINT (-81.4375333330916 27.8346694443497)           NaN         NaN
# 2   POINT (-105.41892222264 36.7097944443651)           NaN         NaN
# 3  POINT (-70.7138888886801 41.7549999998191)           NaN         NaN
# 4  POINT (-71.4982333334652 43.1143166664442)           NaN         NaN
#
#    Magnetic_Variation     State_Name Official_Facility_Name  \
# 0                 NaN     New Jersey                 Heaton
# 1                 NaN        Florida                 Timmer
# 2                 NaN     New Mexico              Red River
# 3                 NaN  Massachusetts         Tobey Hospital
# 4                 NaN  New Hampshire                  Scott
#
#    Elevation_Nearest_Tenth_Of_A_Foot_Msl  \
# 0                                  942.0
# 1                                  104.0
# 2                                 8617.0
# 3                                   86.0
# 4                                  580.0
#
#   Has_Been_Designated_As_A_Customs_Landing_Rights_Airport Location_Identifier  \
# 0                                                NaN                     27JY
# 1                                                NaN                     6FL7
# 2                                                NaN                      N02
# 3                                                NaN                     70MA
# 4                                                NaN                     2NH3
#
#    Departing_Flights  ... Facility_Type Arriving_Flights  \
# 0                NaN  ...      Heliport              NaN
# 1                NaN  ...      Heliport              NaN
# 2                NaN  ...      Heliport              NaN
# 3                NaN  ...      Heliport              NaN
# 4                NaN  ...      Heliport              NaN
#
#   Has_Been_Designated_As_An_International_Airport  Icao_Identifier  \
# 0                                             NaN              NaN
# 1                                             NaN              NaN
# 2                                             NaN              NaN
# 3                                             NaN              NaN
# 4                                             NaN              NaN
#
#     City_Name Associated_Aeronautical_Chart Airport_Activation_Date_Mm_Yyyy  \
# 0      Newton                      New York                         06/2007
# 1  Lake Wales                         Miami                         11/2005
# 2   Red River                        Denver                         05/2009
# 3     Wareham                      New York                         06/2006
# 4         Bow                      New York                         10/2004
#
#   County_s_State_Post_Office_Code     SHAPE_X    SHAPE_Y
# 0                              NJ  -74.822750  41.126178
# 1                              FL  -81.437533  27.834669
# 2                              NM -105.418922  36.709794
# 3                              MA  -70.713889  41.755000
# 4                              NH  -71.498233  43.114317
#
# [5 rows x 22 columns]

# %%
fig = plt.figure(figsize=(15, 8), dpi=80)
ax = fig.add_subplot(111)
ax.scatter(df_heliport['SHAPE_X'], df_heliport['SHAPE_Y'])
plt.grid()
# ax.set_title('EM-GMM Algorithm log Likelihood Plot')
# ax.set_xlabel('Iterations')
# ax.set_ylabel('log Likelihood')
